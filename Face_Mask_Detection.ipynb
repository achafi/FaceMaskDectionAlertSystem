# %%
# Configuration related preprocessing step before mounting the drive
# !apt-get install -y -qq software-properties-common python-software-properties module-init-tools
# !add-apt-repository -y ppa:alessandro-strada/ppa 2>&1 > /dev/null
# !apt-get update -qq 2>&1 > /dev/null
# !apt-get -y install -qq google-drive-ocamlfuse fuse
from google.colab import auth
auth.authenticate_user()
from oauth2client.client import GoogleCredentials
creds = GoogleCredentials.get_application_default()
import getpass
# !google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret} < /dev/null 2>&1 | grep URL
vcode = getpass.getpass()
# !echo {vcode} | google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret}
# Out:
# E: Package 'python-software-properties' has no installation candidate
# Selecting previously unselected package google-drive-ocamlfuse.
# (Reading database ... 144579 files and directories currently installed.)
# Preparing to unpack .../google-drive-ocamlfuse_0.7.22-0ubuntu3~ubuntu18.04.1_amd64.deb ...
# Unpacking google-drive-ocamlfuse (0.7.22-0ubuntu3~ubuntu18.04.1) ...
# Setting up google-drive-ocamlfuse (0.7.22-0ubuntu3~ubuntu18.04.1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Go to the following link in your browser:
#
#     https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=openid+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fuserinfo.email+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fcloud-platform+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fappengine.admin+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fcompute+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Faccounts.reauth+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&code_challenge=YJQqvPUWs5BBgqX45HnblzIVgAyRVAfY_fGeNmYdALg&code_challenge_method=S256&access_type=offline&response_type=code&prompt=select_account
#
#
# Enter verification code: https://colab.research.google.com/drive/1Rz-BEmNhneLqKzslITP1YjxIX6OKngXd
# ---------------------------------------------------------------------------
# AuthorizationError                        Traceback (most recent call last)
# <ipython-input-1-0633b909157f> in <module>()
#       5 get_ipython().system('apt-get -y install -qq google-drive-ocamlfuse fuse')
#       6 from google.colab import auth
# ----> 7 auth.authenticate_user()
#       8 from oauth2client.client import GoogleCredentials
#       9 creds = GoogleCredentials.get_application_default()
#
# /usr/local/lib/python3.6/dist-packages/google/colab/auth.py in authenticate_user(clear_output)
#     149     context_manager = _output.temporary if clear_output else _noop
#     150     with context_manager():
# --> 151       _gcloud_login()
#     152     _install_adc()
#     153     colab_tpu_addr = _os.environ.get('COLAB_TPU_ADDR', '')
#
# /usr/local/lib/python3.6/dist-packages/google/colab/auth.py in _gcloud_login()
#      99     _os.remove(name)
#     100   if gcloud_process.returncode:
# --> 101     raise _errors.AuthorizationError('Error fetching credentials')
#     102
#     103
#
# AuthorizationError: Error fetching credentials

# %%
#Mount the google drive
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ### **Data Pre-processing**

# %%
# Import Necessary libraries
import os 

# Set Directory path for Dataset
os.chdir("/content/drive/My Drive/FacemaskDetectionSystem")
Dataset = 'Dataset'
Data_Dir = os.listdir(Dataset)
print(Data_Dir)
# Out:
# ['without_mask', 'with_mask']

# %%
# Import Necessary libraries
import cv2
import numpy as np
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split

# Dimension of a single image
img_rows, img_cols = 56,56

images = []
labels = []

for category in Data_Dir:
  folder_path = os.path.join(Dataset, category)
  for img in os.listdir(folder_path):
    img_path = os.path.join(folder_path, img)
    img = cv2.imread(img_path)

    try:
      # Converting the image into gray scale
      grayscale_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

      # resizing the gray scaled image into size 56*56 in order to keep size of the images consistent
      resized_img = cv2.resize(grayscale_img, (img_rows, img_cols))
      images.append(resized_img)
      labels.append(category)

      # Exception Handling in case any error occurs
    except Exception as e:
      print("Exception : ", e)

# normalizing the image
images = np.array(images)/255.0
# reshaping the image's array
images = np.reshape(images, (images.shape[0], img_rows, img_cols,1))

# Perform one hot encoding on the labeles since the label are in texutual form
lb = LabelBinarizer()
labels = lb.fit_transform(labels)
labels = to_categorical(labels)
labels = np.array(labels)

(train_X, test_X, train_y, test_y) = train_test_split(images, labels, test_size=0.25, 
                                                      random_state=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-084440c89642> in <module>()
#      12 labels = []
#      13
# ---> 14 for category in Data_Dir:
#      15   folder_path = os.path.join(Dataset, category)
#      16   for img in os.listdir(folder_path):
#
# NameError: name 'Data_Dir' is not defined

# %% [markdown]
# ### Build Convolutional neural network (CNN) Classification Model

# %%
# Import Necessary Keras Libraries
from keras.models import Sequential
from keras.layers import Dense,Activation,Flatten,Dropout
from keras.layers import Conv2D,MaxPooling2D

# Define model paramters
num_classes = 2
batch_size = 32

# Build CNN model using Sequential API
model=Sequential()

#First layer group containing Convolution, Relu and MaxPooling layers
model.add(Conv2D(64,(3,3),input_shape=(img_rows, img_cols, 1)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

#Second layer group containing Convolution, Relu and MaxPooling layers
model.add(Conv2D(128,(3,3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

#Flatten and Dropout Layer to stack the output convolutions above as well as cater overfitting
model.add(Flatten())
model.add(Dropout(0.5))

# Softmax Classifier
model.add(Dense(64,activation='relu'))
model.add(Dense(num_classes,activation='softmax'))

print(model.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 54, 54, 64)        640
# _________________________________________________________________
# activation_2 (Activation)    (None, 54, 54, 64)        0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 27, 27, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 25, 25, 128)       73856
# _________________________________________________________________
# activation_3 (Activation)    (None, 25, 25, 128)       0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 12, 12, 128)       0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 18432)             0
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                1179712
# _________________________________________________________________
# dense_3 (Dense)              (None, 2)                 130
# =================================================================
# Total params: 1,254,338
# Trainable params: 1,254,338
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# Plot the **model**

# %%
# Plot the model
from keras.utils.vis_utils import plot_model
plot_model(model, to_file='face_mask_detection_architecture.png')

# %% [markdown]
# ### Train the model

# %%
from keras.optimizers import Adam

epochs = 50

model.compile(loss = 'categorical_crossentropy',
              optimizer = Adam(lr=0.001),
              metrics = ['accuracy'])

fitted_model = model.fit(
    train_X,
    train_y,
    epochs = epochs,
    validation_split=0.25)
# Out:
# Epoch 1/50
# 14/14 [==============================] - 0s 19ms/step - loss: 0.6884 - accuracy: 0.5388 - val_loss: 0.6421 - val_accuracy: 0.6054
# Epoch 2/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.6031 - accuracy: 0.6689 - val_loss: 0.5293 - val_accuracy: 0.7619
# Epoch 3/50
# 14/14 [==============================] - 0s 9ms/step - loss: 0.5036 - accuracy: 0.7648 - val_loss: 0.4695 - val_accuracy: 0.7755
# Epoch 4/50
# 14/14 [==============================] - 0s 9ms/step - loss: 0.3747 - accuracy: 0.8447 - val_loss: 0.3050 - val_accuracy: 0.8912
# Epoch 5/50
# 14/14 [==============================] - 0s 9ms/step - loss: 0.2830 - accuracy: 0.8881 - val_loss: 0.2286 - val_accuracy: 0.9116
# Epoch 6/50
# 14/14 [==============================] - 0s 8ms/step - loss: 0.2026 - accuracy: 0.9201 - val_loss: 0.2058 - val_accuracy: 0.9456
# Epoch 7/50
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1940 - accuracy: 0.9041 - val_loss: 0.2408 - val_accuracy: 0.8912
# Epoch 8/50
# 14/14 [==============================] - 0s 8ms/step - loss: 0.1749 - accuracy: 0.9178 - val_loss: 0.1873 - val_accuracy: 0.9388
# Epoch 9/50
# 14/14 [==============================] - 0s 8ms/step - loss: 0.1379 - accuracy: 0.9429 - val_loss: 0.1653 - val_accuracy: 0.9592
# Epoch 10/50
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0836 - accuracy: 0.9772 - val_loss: 0.1542 - val_accuracy: 0.9660
# Epoch 11/50
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0769 - accuracy: 0.9772 - val_loss: 0.1866 - val_accuracy: 0.9388
# Epoch 12/50
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0627 - accuracy: 0.9772 - val_loss: 0.1735 - val_accuracy: 0.9524
# Epoch 13/50
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0784 - accuracy: 0.9749 - val_loss: 0.2288 - val_accuracy: 0.9320
# Epoch 14/50
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0845 - accuracy: 0.9726 - val_loss: 0.1886 - val_accuracy: 0.9456
# Epoch 15/50
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0603 - accuracy: 0.9795 - val_loss: 0.1591 - val_accuracy: 0.9592
# Epoch 16/50
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0619 - accuracy: 0.9749 - val_loss: 0.2439 - val_accuracy: 0.8912
# Epoch 17/50
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0457 - accuracy: 0.9932 - val_loss: 0.1859 - val_accuracy: 0.9320
# Epoch 18/50
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0324 - accuracy: 0.9886 - val_loss: 0.1931 - val_accuracy: 0.9252
# Epoch 19/50
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0370 - accuracy: 0.9840 - val_loss: 0.1641 - val_accuracy: 0.9592
# Epoch 20/50
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0240 - accuracy: 0.9954 - val_loss: 0.1666 - val_accuracy: 0.9524
# Epoch 21/50
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0237 - accuracy: 0.9954 - val_loss: 0.1842 - val_accuracy: 0.9524
# Epoch 22/50
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0244 - accuracy: 0.9932 - val_loss: 0.2093 - val_accuracy: 0.9524
# Epoch 23/50
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0346 - accuracy: 0.9817 - val_loss: 0.1813 - val_accuracy: 0.9524
# Epoch 24/50
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0407 - accuracy: 0.9863 - val_loss: 0.1895 - val_accuracy: 0.9592
# Epoch 25/50
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0365 - accuracy: 0.9932 - val_loss: 0.1809 - val_accuracy: 0.9456
# Epoch 26/50
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0278 - accuracy: 0.9932 - val_loss: 0.2571 - val_accuracy: 0.9320
# Epoch 27/50
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0445 - accuracy: 0.9863 - val_loss: 0.2105 - val_accuracy: 0.9524
# Epoch 28/50
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0283 - accuracy: 0.9954 - val_loss: 0.1831 - val_accuracy: 0.9388
# Epoch 29/50
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0207 - accuracy: 0.9954 - val_loss: 0.1807 - val_accuracy: 0.9524
# Epoch 30/50
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0173 - accuracy: 0.9954 - val_loss: 0.1964 - val_accuracy: 0.9456
# Epoch 31/50
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0305 - accuracy: 0.9886 - val_loss: 0.2043 - val_accuracy: 0.9524
# Epoch 32/50
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0116 - accuracy: 1.0000 - val_loss: 0.1936 - val_accuracy: 0.9524
# Epoch 33/50
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0139 - accuracy: 0.9977 - val_loss: 0.2191 - val_accuracy: 0.9524
# Epoch 34/50
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0187 - accuracy: 0.9954 - val_loss: 0.2339 - val_accuracy: 0.9524
# Epoch 35/50
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0179 - accuracy: 0.9932 - val_loss: 0.2150 - val_accuracy: 0.9456
# Epoch 36/50
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0237 - accuracy: 0.9954 - val_loss: 0.2525 - val_accuracy: 0.9388
# Epoch 37/50
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0332 - accuracy: 0.9863 - val_loss: 0.2296 - val_accuracy: 0.9456
# Epoch 38/50
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0379 - accuracy: 0.9886 - val_loss: 0.2477 - val_accuracy: 0.9320
# Epoch 39/50
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0200 - accuracy: 0.9886 - val_loss: 0.2521 - val_accuracy: 0.9320
# Epoch 40/50
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0228 - accuracy: 0.9954 - val_loss: 0.2271 - val_accuracy: 0.9524
# Epoch 41/50
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0117 - accuracy: 0.9954 - val_loss: 0.3132 - val_accuracy: 0.9320
# Epoch 42/50
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0157 - accuracy: 0.9932 - val_loss: 0.4158 - val_accuracy: 0.9116
# Epoch 43/50
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0207 - accuracy: 0.9932 - val_loss: 0.2876 - val_accuracy: 0.9252
# Epoch 44/50
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0184 - accuracy: 0.9932 - val_loss: 0.2432 - val_accuracy: 0.9456
# Epoch 45/50
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0066 - accuracy: 1.0000 - val_loss: 0.2447 - val_accuracy: 0.9524
# Epoch 46/50
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.2566 - val_accuracy: 0.9456
# Epoch 47/50
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0058 - accuracy: 0.9977 - val_loss: 0.2545 - val_accuracy: 0.9524
# Epoch 48/50
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.2515 - val_accuracy: 0.9524
# Epoch 49/50
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.2565 - val_accuracy: 0.9524
# Epoch 50/50
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0048 - accuracy: 0.9977 - val_loss: 0.2708 - val_accuracy: 0.9456

# %% [markdown]
# ### Plot the Training Loss & **Accuracy**

# %%
from matplotlib import pyplot as plt
# Plot Training and Validation Loss
plt.plot(fitted_model.history['loss'],'r',label='training loss')
plt.plot(fitted_model.history['val_loss'],label='validation loss')
plt.xlabel('Number of Epochs')
plt.ylabel('Loss Value')
plt.legend()
plt.show()

# Plot Training and Validation Accuracy
plt.plot(fitted_model.history['accuracy'],'r',label='training accuracy')
plt.plot(fitted_model.history['val_accuracy'],label='validation accuracy')
plt.xlabel('Number of Epochs')
plt.ylabel('Accuracy Value')
plt.legend()
plt.show()

# %% [markdown]
# we can see that the model is overfitted since the gap of training and validation loss is not minimal.

# %% [markdown]
# ### Save or Serialize the Model

# %%
# Save or Serialize the model with the name face_mask_detection_alert_system
model.save('face_mask_detection_alert_system1.h5')

# %%
# Import Necessary Keras Libraries
from keras.models import Sequential
from keras.layers import Dense,Activation,Flatten,Dropout
from keras.layers import Conv2D,MaxPooling2D

model = Sequential()
model.add(Conv2D(32, (3,3), activation='relu', input_shape=(64,64,3)))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(32, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
# Further Adding the NeuralNet in ConvNet Model
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
# Plot the model
from keras.utils.vis_utils import plot_model
plot_model(model, to_file='covid19_xray_detection_architecture.png')

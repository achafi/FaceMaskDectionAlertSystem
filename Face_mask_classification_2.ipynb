# %%
# Configuration related preprocessing step before mounting the drive
# !apt-get install -y -qq software-properties-common python-software-properties module-init-tools
# !add-apt-repository -y ppa:alessandro-strada/ppa 2>&1 > /dev/null
# !apt-get update -qq 2>&1 > /dev/null
# !apt-get -y install -qq google-drive-ocamlfuse fuse
from google.colab import auth
auth.authenticate_user()
from oauth2client.client import GoogleCredentials
creds = GoogleCredentials.get_application_default()
import getpass
# !google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret} < /dev/null 2>&1 | grep URL
vcode = getpass.getpass()
# !echo {vcode} | google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret}
# Out:
# E: Package 'python-software-properties' has no installation candidate
# Selecting previously unselected package google-drive-ocamlfuse.
# (Reading database ... 144579 files and directories currently installed.)
# Preparing to unpack .../google-drive-ocamlfuse_0.7.22-0ubuntu3~ubuntu18.04.1_amd64.deb ...
# Unpacking google-drive-ocamlfuse (0.7.22-0ubuntu3~ubuntu18.04.1) ...
# Setting up google-drive-ocamlfuse (0.7.22-0ubuntu3~ubuntu18.04.1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# ··········
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# Please enter the verification code: Access token retrieved correctly.

# %%
#Mount the google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# 4/4AFjKChWUYVp8jfYdZfjHp9mB-2DwH8mHwMnIQqcUdgqnQfigkR0t_o
# Mounted at /content/drive

# %%
# Import Necessary libraries
import os 

# Set Directory path for Dataset
os.chdir("/content/drive/My Drive/FacemaskDetectionSystem")
data_path = 'Dataset'
categories=os.listdir(data_path)
labels=[i for i in range(len(categories))]

label_dict=dict(zip(categories,labels)) #empty dictionary

print(label_dict)
print(categories)
print(labels)
# Out:
# {'without_mask': 0, 'with_mask': 1}
# ['without_mask', 'with_mask']
# [0, 1]

# %%
import cv2
img_size=100
data=[]
target=[]


for category in categories:
    folder_path=os.path.join(data_path,category)
    img_names=os.listdir(folder_path)
        
    for img_name in img_names:
        img_path=os.path.join(folder_path,img_name)
        img=cv2.imread(img_path)

        try:
            gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)           
            #Coverting the image into gray scale
            resized=cv2.resize(gray,(img_size,img_size))
            #resizing the gray scale into 50x50, since we need a fixed common size for all the images in the dataset
            data.append(resized)
            target.append(label_dict[category])
            #appending the image and the label(categorized) into the list (dataset)

        except Exception as e:
            print('Exception:',e)
            #if any exception rasied, the exception will be printed here. And pass to the next image

# %%
import numpy as np

data=np.array(data)/255.0
data=np.reshape(data,(data.shape[0],img_size,img_size,1))
target=np.array(target)

from keras.utils import np_utils

new_target=np_utils.to_categorical(target)

# %%
np.save('data',data)
np.save('target',new_target)

# %%
import numpy as np

data=np.load('data.npy')
target=np.load('target.npy')

# %%
from keras.models import Sequential
from keras.layers import Dense,Activation,Flatten,Dropout
from keras.layers import Conv2D,MaxPooling2D
from keras.callbacks import ModelCheckpoint

model=Sequential()

model.add(Conv2D(200,(3,3),input_shape=data.shape[1:]))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
#The first CNN layer followed by Relu and MaxPooling layers

model.add(Conv2D(100,(3,3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
#The second convolution layer followed by Relu and MaxPooling layers

model.add(Flatten())
model.add(Dropout(0.5))
#Flatten layer to stack the output convolutions from second convolution layer
model.add(Dense(50,activation='relu'))
#Dense layer of 64 neurons
model.add(Dense(2,activation='softmax'))
#The Final layer with two outputs for two categories

model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
from sklearn.model_selection import train_test_split

train_data,test_data,train_target,test_target=train_test_split(data,target,test_size=0.1)

# %%
checkpoint = ModelCheckpoint('model-{epoch:03d}.model',monitor='val_loss',verbose=0,save_best_only=True,mode='auto')
history=model.fit(train_data,train_target,epochs=20,callbacks=[checkpoint],validation_split=0.2)
# Out:
# Epoch 1/20
# 32/32 [==============================] - ETA: 0s - loss: 0.7890 - accuracy: 0.4975WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/tracking/tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/tracking/tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: model-001.model/assets
# 32/32 [==============================] - 4s 111ms/step - loss: 0.7890 - accuracy: 0.4975 - val_loss: 0.6931 - val_accuracy: 0.4900
# Epoch 2/20
# 31/32 [============================>.] - ETA: 0s - loss: 0.6939 - accuracy: 0.4940INFO:tensorflow:Assets written to: model-002.model/assets
# 32/32 [==============================] - 3s 84ms/step - loss: 0.6938 - accuracy: 0.4955 - val_loss: 0.6795 - val_accuracy: 0.5458
# Epoch 3/20
# 31/32 [============================>.] - ETA: 0s - loss: 0.6495 - accuracy: 0.6341INFO:tensorflow:Assets written to: model-003.model/assets
# 32/32 [==============================] - 3s 93ms/step - loss: 0.6489 - accuracy: 0.6344 - val_loss: 0.6083 - val_accuracy: 0.6693
# Epoch 4/20
# 31/32 [============================>.] - ETA: 0s - loss: 0.5893 - accuracy: 0.6825INFO:tensorflow:Assets written to: model-004.model/assets
# 32/32 [==============================] - 3s 81ms/step - loss: 0.5883 - accuracy: 0.6833 - val_loss: 0.5991 - val_accuracy: 0.6892
# Epoch 5/20
# 31/32 [============================>.] - ETA: 0s - loss: 0.4975 - accuracy: 0.7681INFO:tensorflow:Assets written to: model-005.model/assets
# 32/32 [==============================] - 2s 78ms/step - loss: 0.4990 - accuracy: 0.7672 - val_loss: 0.4524 - val_accuracy: 0.8247
# Epoch 6/20
# 31/32 [============================>.] - ETA: 0s - loss: 0.4045 - accuracy: 0.8196INFO:tensorflow:Assets written to: model-006.model/assets
# 32/32 [==============================] - 2s 69ms/step - loss: 0.4046 - accuracy: 0.8192 - val_loss: 0.3730 - val_accuracy: 0.8566
# Epoch 7/20
# 31/32 [============================>.] - ETA: 0s - loss: 0.3434 - accuracy: 0.8599INFO:tensorflow:Assets written to: model-007.model/assets
# 32/32 [==============================] - 3s 83ms/step - loss: 0.3418 - accuracy: 0.8611 - val_loss: 0.3419 - val_accuracy: 0.8765
# Epoch 8/20
# 31/32 [============================>.] - ETA: 0s - loss: 0.2522 - accuracy: 0.9062INFO:tensorflow:Assets written to: model-008.model/assets
# 32/32 [==============================] - 2s 76ms/step - loss: 0.2527 - accuracy: 0.9061 - val_loss: 0.2551 - val_accuracy: 0.9163
# Epoch 9/20
# 31/32 [============================>.] - ETA: 0s - loss: 0.1968 - accuracy: 0.9183INFO:tensorflow:Assets written to: model-009.model/assets
# 32/32 [==============================] - 2s 64ms/step - loss: 0.1954 - accuracy: 0.9191 - val_loss: 0.2033 - val_accuracy: 0.9243
# Epoch 10/20
# 31/32 [============================>.] - ETA: 0s - loss: 0.1412 - accuracy: 0.9365INFO:tensorflow:Assets written to: model-010.model/assets
# 32/32 [==============================] - 2s 67ms/step - loss: 0.1411 - accuracy: 0.9361 - val_loss: 0.1570 - val_accuracy: 0.9402
# Epoch 11/20
# 32/32 [==============================] - 1s 38ms/step - loss: 0.1759 - accuracy: 0.9261 - val_loss: 0.2238 - val_accuracy: 0.9004
# Epoch 12/20
# 31/32 [============================>.] - ETA: 0s - loss: 0.1019 - accuracy: 0.9647INFO:tensorflow:Assets written to: model-012.model/assets
# 32/32 [==============================] - 2s 69ms/step - loss: 0.1023 - accuracy: 0.9650 - val_loss: 0.1386 - val_accuracy: 0.9402
# Epoch 13/20
# 31/32 [============================>.] - ETA: 0s - loss: 0.0996 - accuracy: 0.9617INFO:tensorflow:Assets written to: model-013.model/assets
# 32/32 [==============================] - 2s 66ms/step - loss: 0.0988 - accuracy: 0.9620 - val_loss: 0.1218 - val_accuracy: 0.9522
# Epoch 14/20
# 31/32 [============================>.] - ETA: 0s - loss: 0.0703 - accuracy: 0.9708INFO:tensorflow:Assets written to: model-014.model/assets
# 32/32 [==============================] - 3s 80ms/step - loss: 0.0701 - accuracy: 0.9710 - val_loss: 0.0938 - val_accuracy: 0.9641
# Epoch 15/20
# 32/32 [==============================] - 1s 38ms/step - loss: 0.0594 - accuracy: 0.9740 - val_loss: 0.0971 - val_accuracy: 0.9681
# Epoch 16/20
# 32/32 [==============================] - 1s 38ms/step - loss: 0.0558 - accuracy: 0.9790 - val_loss: 0.1041 - val_accuracy: 0.9602
# Epoch 17/20
# 32/32 [==============================] - 1s 38ms/step - loss: 0.0542 - accuracy: 0.9790 - val_loss: 0.1015 - val_accuracy: 0.9681
# Epoch 18/20
# 31/32 [============================>.] - ETA: 0s - loss: 0.0359 - accuracy: 0.9899INFO:tensorflow:Assets written to: model-018.model/assets
# 32/32 [==============================] - 2s 69ms/step - loss: 0.0358 - accuracy: 0.9900 - val_loss: 0.0821 - val_accuracy: 0.9761
# Epoch 19/20
# 32/32 [==============================] - 1s 39ms/step - loss: 0.0329 - accuracy: 0.9900 - val_loss: 0.1671 - val_accuracy: 0.9482
# Epoch 20/20
# 32/32 [==============================] - 1s 38ms/step - loss: 0.0326 - accuracy: 0.9890 - val_loss: 0.1121 - val_accuracy: 0.9721

# %%
from matplotlib import pyplot as plt

plt.plot(history.history['loss'],'r',label='training loss')
plt.plot(history.history['val_loss'],label='validation loss')
plt.xlabel('# epochs')
plt.ylabel('loss')
plt.legend()
plt.show()

# %%
plt.plot(history.history['accuracy'],'r',label='training accuracy')
plt.plot(history.history['val_accuracy'],label='validation accuracy')
plt.xlabel('# epochs')
plt.ylabel('accuracy')
plt.legend()
plt.show()

# %%
print(model.evaluate(test_data,test_target))
# Out:
# 5/5 [==============================] - 0s 21ms/step - loss: 0.2279 - accuracy: 0.9286
# [0.2279343456029892, 0.9285714030265808]

# %%
# Save or Serialize the model with the name face_mask_detection_alert_system
model.save('face_mask_detection_model.h5')
